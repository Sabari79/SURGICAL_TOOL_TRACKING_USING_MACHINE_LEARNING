# %%
from ultralytics import YOLO
import cv2

# Load YOLO model
model_path = r"D:\project\yolo_training\tool_tracking7\weights\best.pt"  # Update with correct path
model = YOLO(model_path)

# Initialize video capture (replace with your video path)
video_path = "videoplayback (1).mp4"  # Update with your video path
cap = cv2.VideoCapture(video_path)

# Define desired width and height for resizing
resize_width = 640  # Desired width
resize_height = 480  # Desired height

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Resize the frame to the desired size
    frame_resized = cv2.resize(frame, (resize_width, resize_height))

    # Run YOLO detection on the current frame
    results = model(frame_resized)

    # Convert frame to RGB for display
    frame_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)

    # Process detections and draw bounding boxes on the frame
    for result in results:
        for box in result.boxes:
            conf = box.conf[0].item()
            
            # Only display class name and box if confidence is higher than 75%
            if conf > 0.75:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls = int(box.cls[0].item())

                # Create label text with class name and confidence
                label = f"{model.names[cls]}: {conf:.2f}"

                # Set font scale and thickness
                font_scale = 1.0
                font_thickness = 2
                font = cv2.FONT_HERSHEY_SIMPLEX

                # Get text size
                text_size, baseline = cv2.getTextSize(label, font, font_scale, font_thickness)
                text_w, text_h = text_size

                # Ensure text stays within the image bounds
                text_x = max(10, x1)  # Avoid going off the left side
                text_y = max(text_h + 10, y1 - 10)  # Ensure text does not go above the image

                # Draw a filled rectangle for the text background (wider for better visibility)
                cv2.rectangle(frame_rgb, (text_x - 5, text_y - text_h - 5),
                              (text_x + text_w + 5, text_y + baseline + 5), (0, 255, 0), -1)

                # Draw the text label
                cv2.putText(frame_rgb, label, (text_x, text_y), font, font_scale, (0, 0, 0), font_thickness)

                # Draw the bounding box
                cv2.rectangle(frame_rgb, (x1, y1), (x2, y2), (0, 255, 0), 3)

    # Display the resized frame using OpenCV
    cv2.imshow("YOLOv8 Tool Detection", frame_rgb)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 56.7ms
# Speed: 2.3ms preprocess, 56.7ms inference, 97.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 36.7ms
# Speed: 3.5ms preprocess, 36.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 37.7ms
# Speed: 3.1ms preprocess, 37.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 37.8ms
# Speed: 2.0ms preprocess, 37.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 34.9ms
# Speed: 1.6ms preprocess, 34.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 33.5ms
# Speed: 3.2ms preprocess, 33.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 straight mayo scissors, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 straight mayo scissors, 33.0ms
# Speed: 2.3ms preprocess, 33.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.6ms
# Speed: 2.6ms preprocess, 33.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 straight mayo scissors, 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 straight mayo scissors, 33.2ms
# Speed: 3.5ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 34.4ms
# Speed: 2.3ms preprocess, 34.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 34.8ms
# Speed: 2.7ms preprocess, 34.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 33.7ms
# Speed: 2.5ms preprocess, 33.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 34.5ms
# Speed: 1.8ms preprocess, 34.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 2 straight mayo scissors, 34.2ms
# Speed: 2.7ms preprocess, 34.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 2 straight mayo scissors, 34.5ms
# Speed: 2.1ms preprocess, 34.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 3 straight mayo scissors, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 scalpels, 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 scalpels, 33.5ms
# Speed: 2.3ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 32.9ms
# Speed: 2.2ms preprocess, 32.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 35.0ms
# Speed: 2.5ms preprocess, 35.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 35.0ms
# Speed: 1.8ms preprocess, 35.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 34.7ms
# Speed: 1.8ms preprocess, 34.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.6ms
# Speed: 1.4ms preprocess, 33.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.2ms
# Speed: 2.4ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 scalpels, 35.1ms
# Speed: 1.7ms preprocess, 35.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 scalpels, 35.8ms
# Speed: 1.6ms preprocess, 35.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 scalpels, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 scalpels, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 scalpels, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 scalpels, 35.1ms
# Speed: 1.8ms preprocess, 35.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 scalpels, 34.8ms
# Speed: 1.8ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 scalpels, 34.0ms
# Speed: 2.5ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 straight mayo scissor, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 1 straight mayo scissor, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 1 straight mayo scissor, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 curved mayo scissor, 2 scalpels, 1 straight mayo scissor, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 curved mayo scissor, 2 scalpels, 1 straight mayo scissor, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 2 straight mayo scissors, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 1 straight mayo scissor, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scalpels, 1 straight mayo scissor, 35.5ms
# Speed: 2.6ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 scalpels, 34.9ms
# Speed: 1.7ms preprocess, 34.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 scalpels, 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 scalpels, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 2 straight mayo scissors, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 2 straight mayo scissors, 34.7ms
# Speed: 1.6ms preprocess, 34.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scalpel, 1 straight mayo scissor, 33.7ms
# Speed: 2.2ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
